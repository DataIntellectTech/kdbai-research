# %% [markdown]
# # kdb.ai Classification Network Template

# %% [markdown]
# The following document is a template for converting kdb.ai into a classification network based on pre-defined models.
#
# This document will be split into 3 parts. The first section will create kdb.ai embeddings on a data set using a model that you have already created. The second step will create embeddings for your test images and is a mandatory step for use of this document. The third step will perfrom classification on the image.

# %% [markdown]
# ## Section 0: Setup

# %% [markdown]
# The following section will import all of the required modules and define helper functions that are necessary for this document, and this section should always be run before using the document.

# %%
import os

# %%
### ignore tensorflow warnings
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# %%
# force tensorflow to use CPU only
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
# download data
from zipfile import ZipFile

# %%
# embeddings
from tensorflow.keras.utils import image_dataset_from_directory
from huggingface_hub import from_pretrained_keras
from PIL import Image
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
# timing
from tqdm.auto import tqdm

# %%
# vector DB
import kdbai_client as kdbai
from getpass import getpass
import time

# %%
from pathlib import Path
import imghdr

# %%
import kdbai_client as kdbai
session = kdbai.Session(endpoint='http://localhost:8082')

# %%
import math
import statistics

# %% [markdown]
# ### Defining Helper Functions:

# %%
def show_df(df: pd.DataFrame) -> pd.DataFrame:
    print(df.shape)
    return df.head()

# %%
def extract_file_paths_from_folder(parent_dir: str) -> dict:
    image_paths = {}
    for sub_folder in os.listdir(parent_dir):
        sub_dir = os.path.join(parent_dir, sub_folder)
        image_paths[sub_folder] = [
            os.path.join(sub_dir, file) for file in os.listdir(sub_dir)
        ]
    return image_paths

# %% [markdown]
# ## Section 1: Creating Embeddings for Dataset

# %% [markdown]
# The following section should be used to create embeddings and store them in kdb.ai. If you have already stored your embeddings in a kdb.ai session, you may skip to section 2.

# %% [markdown]
# ### IMPORTANT

# %% [markdown]
# The following cell will search your data folder for files that are incompatible with Tensorflow. These files will then be deleted from the data folder, so it is important that if you want to keep all of these images that you have the data set saved elsewhere as a backup.

# %%
data_dir = "data/"
image_extensions = [".png", ".jpg", ".jpeg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
            print(f"Deleting {filepath} from data folder")
            os.remove("{filepath}")
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
            print(f"Deleting {filepath} from data folder")
            os.remove("{filepath}")

# %% [markdown]
# ### Loading Image Data

# %%
image_paths_map = extract_file_paths_from_folder("data")

# %%
dataset = image_dataset_from_directory(
    "data",
    labels="inferred",
    label_mode="categorical",
    shuffle=False,
    seed=1,
    image_size=(224, 224),
    batch_size=1,
)
# Out:
# Found 2396 files belonging to 5 classes.

# %% [markdown]
# ### Creating Vector Embeddings

# %%
model = tf.keras.models.load_model('saved_model/your_model')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  regnetx064_prestem_rescali  (None, 224, 224, 3)          0         ['input_1[0][0]']
#  ng (Rescaling)
#
#  regnetx064_stem_conv (Conv  (None, 112, 112, 32)         864       ['regnetx064_prestem_rescaling
#  2D)                                                                [0][0]']
#
#  regnetx064_stem_bn (BatchN  (None, 112, 112, 32)         128       ['regnetx064_stem_conv[0][0]']
#  ormalization)
#
#  regnetx064_stem_relu (ReLU  (None, 112, 112, 32)         0         ['regnetx064_stem_bn[0][0]']
#  )
#
#  regnetx064_Stage_0_XBlock_  (None, 112, 112, 168)        5376      ['regnetx064_stem_relu[0][0]']
#  0_conv_1x1_1 (Conv2D)
#
#  regnetx064_Stage_0_XBlock_  (None, 112, 112, 168)        672       ['regnetx064_Stage_0_XBlock_0_
#  0_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_0_XBlock_  (None, 112, 112, 168)        0         ['regnetx064_Stage_0_XBlock_0_
#  0_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          84672     ['regnetx064_Stage_0_XBlock_0_
#  0_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          672       ['regnetx064_Stage_0_XBlock_0_
#  0_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          0         ['regnetx064_Stage_0_XBlock_0_
#  0_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          28224     ['regnetx064_Stage_0_XBlock_0_
#  0_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          5376      ['regnetx064_stem_relu[0][0]']
#  0_skip_1x1 (Conv2D)
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          672       ['regnetx064_Stage_0_XBlock_0_
#  0_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          672       ['regnetx064_Stage_0_XBlock_0_
#  0_skip_bn (BatchNormalizat                                         skip_1x1[0][0]']
#  ion)
#
#  tf.__operators__.add (TFOp  (None, 56, 56, 168)          0         ['regnetx064_Stage_0_XBlock_0_
#  Lambda)                                                            conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_0_XBlock_0_
#                                                                     skip_bn[0][0]']
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          0         ['tf.__operators__.add[0][0]']
#  0_exit_relu (ReLU)
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          28224     ['regnetx064_Stage_0_XBlock_0_
#  1_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          672       ['regnetx064_Stage_0_XBlock_1_
#  1_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          0         ['regnetx064_Stage_0_XBlock_1_
#  1_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          84672     ['regnetx064_Stage_0_XBlock_1_
#  1_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          672       ['regnetx064_Stage_0_XBlock_1_
#  1_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          0         ['regnetx064_Stage_0_XBlock_1_
#  1_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          28224     ['regnetx064_Stage_0_XBlock_1_
#  1_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          672       ['regnetx064_Stage_0_XBlock_1_
#  1_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  tf.__operators__.add_1 (TF  (None, 56, 56, 168)          0         ['regnetx064_Stage_0_XBlock_1_
#  OpLambda)                                                          conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_0_XBlock_0_
#                                                                     exit_relu[0][0]']
#
#  regnetx064_Stage_0_XBlock_  (None, 56, 56, 168)          0         ['tf.__operators__.add_1[0][0]
#  1_exit_relu (ReLU)                                                 ']
#
#  regnetx064_Stage_1_XBlock_  (None, 56, 56, 392)          65856     ['regnetx064_Stage_0_XBlock_1_
#  0_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 56, 56, 392)          1568      ['regnetx064_Stage_1_XBlock_0_
#  0_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_1_XBlock_  (None, 56, 56, 392)          0         ['regnetx064_Stage_1_XBlock_0_
#  0_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          197568    ['regnetx064_Stage_1_XBlock_0_
#  0_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          1568      ['regnetx064_Stage_1_XBlock_0_
#  0_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          0         ['regnetx064_Stage_1_XBlock_0_
#  0_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          153664    ['regnetx064_Stage_1_XBlock_0_
#  0_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          65856     ['regnetx064_Stage_0_XBlock_1_
#  0_skip_1x1 (Conv2D)                                                exit_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          1568      ['regnetx064_Stage_1_XBlock_0_
#  0_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          1568      ['regnetx064_Stage_1_XBlock_0_
#  0_skip_bn (BatchNormalizat                                         skip_1x1[0][0]']
#  ion)
#
#  tf.__operators__.add_2 (TF  (None, 28, 28, 392)          0         ['regnetx064_Stage_1_XBlock_0_
#  OpLambda)                                                          conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_1_XBlock_0_
#                                                                     skip_bn[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          0         ['tf.__operators__.add_2[0][0]
#  0_exit_relu (ReLU)                                                 ']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          153664    ['regnetx064_Stage_1_XBlock_0_
#  1_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          1568      ['regnetx064_Stage_1_XBlock_1_
#  1_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          0         ['regnetx064_Stage_1_XBlock_1_
#  1_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          197568    ['regnetx064_Stage_1_XBlock_1_
#  1_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          1568      ['regnetx064_Stage_1_XBlock_1_
#  1_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          0         ['regnetx064_Stage_1_XBlock_1_
#  1_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          153664    ['regnetx064_Stage_1_XBlock_1_
#  1_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          1568      ['regnetx064_Stage_1_XBlock_1_
#  1_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  tf.__operators__.add_3 (TF  (None, 28, 28, 392)          0         ['regnetx064_Stage_1_XBlock_1_
#  OpLambda)                                                          conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_1_XBlock_0_
#                                                                     exit_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          0         ['tf.__operators__.add_3[0][0]
#  1_exit_relu (ReLU)                                                 ']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          153664    ['regnetx064_Stage_1_XBlock_1_
#  2_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          1568      ['regnetx064_Stage_1_XBlock_2_
#  2_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          0         ['regnetx064_Stage_1_XBlock_2_
#  2_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          197568    ['regnetx064_Stage_1_XBlock_2_
#  2_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          1568      ['regnetx064_Stage_1_XBlock_2_
#  2_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          0         ['regnetx064_Stage_1_XBlock_2_
#  2_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          153664    ['regnetx064_Stage_1_XBlock_2_
#  2_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          1568      ['regnetx064_Stage_1_XBlock_2_
#  2_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  tf.__operators__.add_4 (TF  (None, 28, 28, 392)          0         ['regnetx064_Stage_1_XBlock_2_
#  OpLambda)                                                          conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_1_XBlock_1_
#                                                                     exit_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          0         ['tf.__operators__.add_4[0][0]
#  2_exit_relu (ReLU)                                                 ']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          153664    ['regnetx064_Stage_1_XBlock_2_
#  3_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          1568      ['regnetx064_Stage_1_XBlock_3_
#  3_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          0         ['regnetx064_Stage_1_XBlock_3_
#  3_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          197568    ['regnetx064_Stage_1_XBlock_3_
#  3_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          1568      ['regnetx064_Stage_1_XBlock_3_
#  3_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          0         ['regnetx064_Stage_1_XBlock_3_
#  3_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          153664    ['regnetx064_Stage_1_XBlock_3_
#  3_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          1568      ['regnetx064_Stage_1_XBlock_3_
#  3_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  tf.__operators__.add_5 (TF  (None, 28, 28, 392)          0         ['regnetx064_Stage_1_XBlock_3_
#  OpLambda)                                                          conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_1_XBlock_2_
#                                                                     exit_relu[0][0]']
#
#  regnetx064_Stage_1_XBlock_  (None, 28, 28, 392)          0         ['tf.__operators__.add_5[0][0]
#  3_exit_relu (ReLU)                                                 ']
#
#  regnetx064_Stage_2_XBlock_  (None, 28, 28, 784)          307328    ['regnetx064_Stage_1_XBlock_3_
#  0_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 28, 28, 784)          3136      ['regnetx064_Stage_2_XBlock_0_
#  0_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_2_XBlock_  (None, 28, 28, 784)          0         ['regnetx064_Stage_2_XBlock_0_
#  0_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          395136    ['regnetx064_Stage_2_XBlock_0_
#  0_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_0_
#  0_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_0_
#  0_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_0_
#  0_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          307328    ['regnetx064_Stage_1_XBlock_3_
#  0_skip_1x1 (Conv2D)                                                exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_0_
#  0_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_0_
#  0_skip_bn (BatchNormalizat                                         skip_1x1[0][0]']
#  ion)
#
#  tf.__operators__.add_6 (TF  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_0_
#  OpLambda)                                                          conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_2_XBlock_0_
#                                                                     skip_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['tf.__operators__.add_6[0][0]
#  0_exit_relu (ReLU)                                                 ']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_0_
#  1_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_1_
#  1_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_1_
#  1_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          395136    ['regnetx064_Stage_2_XBlock_1_
#  1_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_1_
#  1_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_1_
#  1_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_1_
#  1_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_1_
#  1_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  tf.__operators__.add_7 (TF  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_1_
#  OpLambda)                                                          conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_2_XBlock_0_
#                                                                     exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['tf.__operators__.add_7[0][0]
#  1_exit_relu (ReLU)                                                 ']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_1_
#  2_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_2_
#  2_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_2_
#  2_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          395136    ['regnetx064_Stage_2_XBlock_2_
#  2_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_2_
#  2_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_2_
#  2_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_2_
#  2_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_2_
#  2_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  tf.__operators__.add_8 (TF  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_2_
#  OpLambda)                                                          conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_2_XBlock_1_
#                                                                     exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['tf.__operators__.add_8[0][0]
#  2_exit_relu (ReLU)                                                 ']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_2_
#  3_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_3_
#  3_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_3_
#  3_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          395136    ['regnetx064_Stage_2_XBlock_3_
#  3_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_3_
#  3_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_3_
#  3_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_3_
#  3_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_3_
#  3_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  tf.__operators__.add_9 (TF  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_3_
#  OpLambda)                                                          conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_2_XBlock_2_
#                                                                     exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['tf.__operators__.add_9[0][0]
#  3_exit_relu (ReLU)                                                 ']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_3_
#  4_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_4_
#  4_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_4_
#  4_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          395136    ['regnetx064_Stage_2_XBlock_4_
#  4_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_4_
#  4_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_4_
#  4_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_4_
#  4_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_4_
#  4_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  tf.__operators__.add_10 (T  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_4_
#  FOpLambda)                                                         conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_2_XBlock_3_
#                                                                     exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['tf.__operators__.add_10[0][0
#  4_exit_relu (ReLU)                                                 ]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_4_
#  5_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_5_
#  5_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_5_
#  5_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          395136    ['regnetx064_Stage_2_XBlock_5_
#  5_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_5_
#  5_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_5_
#  5_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_5_
#  5_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_5_
#  5_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  tf.__operators__.add_11 (T  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_5_
#  FOpLambda)                                                         conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_2_XBlock_4_
#                                                                     exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['tf.__operators__.add_11[0][0
#  5_exit_relu (ReLU)                                                 ]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_5_
#  6_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_6_
#  6_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_6_
#  6_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          395136    ['regnetx064_Stage_2_XBlock_6_
#  6_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_6_
#  6_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_6_
#  6_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_6_
#  6_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_6_
#  6_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
# ...
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_7_
#  7_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_7_
#  7_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          395136    ['regnetx064_Stage_2_XBlock_7_
#  7_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_7_
#  7_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_7_
#  7_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_7_
#  7_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_7_
#  7_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  tf.__operators__.add_13 (T  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_7_
#  FOpLambda)                                                         conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_2_XBlock_6_
#                                                                     exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['tf.__operators__.add_13[0][0
#  7_exit_relu (ReLU)                                                 ]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_7_
#  8_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_8_
#  8_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_8_
#  8_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          395136    ['regnetx064_Stage_2_XBlock_8_
#  8_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_8_
#  8_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_8_
#  8_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_8_
#  8_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_8_
#  8_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  tf.__operators__.add_14 (T  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_8_
#  FOpLambda)                                                         conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_2_XBlock_7_
#                                                                     exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['tf.__operators__.add_14[0][0
#  8_exit_relu (ReLU)                                                 ]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_8_
#  9_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_9_
#  9_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_9_
#  9_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          395136    ['regnetx064_Stage_2_XBlock_9_
#  9_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_9_
#  9_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_9_
#  9_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          614656    ['regnetx064_Stage_2_XBlock_9_
#  9_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          3136      ['regnetx064_Stage_2_XBlock_9_
#  9_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  tf.__operators__.add_15 (T  (None, 14, 14, 784)          0         ['regnetx064_Stage_2_XBlock_9_
#  FOpLambda)                                                         conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_2_XBlock_8_
#                                                                     exit_relu[0][0]']
#
#  regnetx064_Stage_2_XBlock_  (None, 14, 14, 784)          0         ['tf.__operators__.add_15[0][0
#  9_exit_relu (ReLU)                                                 ]']
#
#  regnetx064_Stage_3_XBlock_  (None, 14, 14, 1624)         1273216   ['regnetx064_Stage_2_XBlock_9_
#  0_conv_1x1_1 (Conv2D)                                              exit_relu[0][0]']
#
#  regnetx064_Stage_3_XBlock_  (None, 14, 14, 1624)         6496      ['regnetx064_Stage_3_XBlock_0_
#  0_conv_1x1_1_bn (BatchNorm                                         conv_1x1_1[0][0]']
#  alization)
#
#  regnetx064_Stage_3_XBlock_  (None, 14, 14, 1624)         0         ['regnetx064_Stage_3_XBlock_0_
#  0_conv_1x1_1_relu (ReLU)                                           conv_1x1_1_bn[0][0]']
#
#  regnetx064_Stage_3_XBlock_  (None, 7, 7, 1624)           818496    ['regnetx064_Stage_3_XBlock_0_
#  0_conv_3x3 (Conv2D)                                                conv_1x1_1_relu[0][0]']
#
#  regnetx064_Stage_3_XBlock_  (None, 7, 7, 1624)           6496      ['regnetx064_Stage_3_XBlock_0_
#  0_conv_3x3_bn (BatchNormal                                         conv_3x3[0][0]']
#  ization)
#
#  regnetx064_Stage_3_XBlock_  (None, 7, 7, 1624)           0         ['regnetx064_Stage_3_XBlock_0_
#  0_conv_3x3_relu (ReLU)                                             conv_3x3_bn[0][0]']
#
#  regnetx064_Stage_3_XBlock_  (None, 7, 7, 1624)           2637376   ['regnetx064_Stage_3_XBlock_0_
#  0_conv_1x1_2 (Conv2D)                                              conv_3x3_relu[0][0]']
#
#  regnetx064_Stage_3_XBlock_  (None, 7, 7, 1624)           1273216   ['regnetx064_Stage_2_XBlock_9_
#  0_skip_1x1 (Conv2D)                                                exit_relu[0][0]']
#
#  regnetx064_Stage_3_XBlock_  (None, 7, 7, 1624)           6496      ['regnetx064_Stage_3_XBlock_0_
#  0_conv_1x1_2_bn (BatchNorm                                         conv_1x1_2[0][0]']
#  alization)
#
#  regnetx064_Stage_3_XBlock_  (None, 7, 7, 1624)           6496      ['regnetx064_Stage_3_XBlock_0_
#  0_skip_bn (BatchNormalizat                                         skip_1x1[0][0]']
#  ion)
#
#  tf.__operators__.add_16 (T  (None, 7, 7, 1624)           0         ['regnetx064_Stage_3_XBlock_0_
#  FOpLambda)                                                         conv_1x1_2_bn[0][0]',
#                                                                      'regnetx064_Stage_3_XBlock_0_
#                                                                     skip_bn[0][0]']
#
#  regnetx064_Stage_3_XBlock_  (None, 7, 7, 1624)           0         ['tf.__operators__.add_16[0][0
#  0_exit_relu (ReLU)                                                 ]']
#
#  global_average_pooling2d (  (None, 1624)                 0         ['regnetx064_Stage_3_XBlock_0_
#  GlobalAveragePooling2D)                                            exit_relu[0][0]']
#
#  dropout (Dropout)           (None, 1624)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout_1 (Dropout)         (None, 1624)                 0         ['dropout[0][0]']
#
#  dropout_2 (Dropout)         (None, 1624)                 0         ['dropout_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 1624)                 0         ['dropout_2[0][0]']
#
#  dense (Dense)               (None, 2048)                 3328000   ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 27986464 (106.76 MB)
# Trainable params: 3328000 (12.70 MB)
# Non-trainable params: 24658464 (94.06 MB)
# __________________________________________________________________________________________________

# %%
# create empty arrays to store the embeddings and labels
embeddings = np.empty([len(dataset), 2048])
labels = np.empty([len(dataset), 5]) # You must replace N in this line with the number of classifications your data set has

# %%
# for each image in dataset, get its embedding and class label
for i, image in tqdm(enumerate(dataset), total=len(dataset)):
    embeddings[i, :] = model.predict(image[0], verbose=0)
    labels[i, :] = image[1]
# Out:
#   0%|          | 0/2396 [00:00<?, ?it/s]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709719292.339503    2265 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %% [markdown]
# ### Defining Class Labels

# %%
sorted(image_paths_map.keys())
# Out:
# ['.ipynb_checkpoints', 'Healthy', 'Mosaic', 'RedRot', 'Rust', 'Yellow']

# %% [markdown]
# If incorrect classification names are present, use the following:

# %%
del image_paths_map['.ipynb_checkpoints']
sorted(image_paths_map.keys())
# Out:
# ['Healthy', 'Mosaic', 'RedRot', 'Rust', 'Yellow']

# %% [markdown]
# And then continue from here:

# %%
# list the classification types in sorted order
classification_types = sorted(image_paths_map.keys())

# %%
# for each vector, save the classification type given by the high index
class_labels = [classification_types[label.argmax()] for label in labels]

# %% [markdown]
# ### Defining Image Filepaths

# %%
# get a single list of all paths
all_paths = []
for _, image_paths in image_paths_map.items():
    all_paths += image_paths

# %%
# sort the source_files in alphanumeric order
sorted_all_paths = sorted(all_paths)

# %% [markdown]
# ### Defining Embedding Dataframe

# %%
embedded_df = pd.DataFrame(
    {
        "source": sorted_all_paths,
        "class": class_labels,
        "embedding": embeddings.tolist(),
    }
)

# %% [markdown]
# If you receive an error on the previous cell stating that the arrays need to be of the same length, you may need to remove the '.ipynb_checkpoints' from each classification within the data set. The following cells will do this, but it is important that you replicate this cell with as many classifications that you have:

# %%
sorted_all_paths.remove('data/Healthy/.ipynb_checkpoints')

# %%
sorted_all_paths.remove('data/Mosaic/.ipynb_checkpoints')

# %%
sorted_all_paths.remove('data/Rust/.ipynb_checkpoints')

# %%
sorted_all_paths.remove('data/RedRot/.ipynb_checkpoints')

# %%
sorted_all_paths.remove('data/Yellow/.ipynb_checkpoints')

# %% [markdown]
# Do this to remove the files from each classification and then continue from here:

# %%
show_df(embedded_df)
# Out:
# (2396, 3)
#                             source    class  \
# 0  data/Healthy/healthy (121).jpeg  Healthy
# 1  data/Healthy/healthy (122).jpeg  Healthy
# 2  data/Healthy/healthy (123).jpeg  Healthy
# 3  data/Healthy/healthy (124).jpeg  Healthy
# 4  data/Healthy/healthy (125).jpeg  Healthy
#
#                                            embedding
# 0  [0.9535317420959473, 0.038117386400699615, 0.0...
# 1  [0.8989417552947998, 0.06690378487110138, 0.00...
# 2  [0.5552961826324463, 0.3637266755104065, 0.025...
# 3  [0.9178681373596191, 0.03479386866092682, 0.00...
# 4  [0.9047070741653442, 0.036002758890390396, 0.0...

# %% [markdown]
# ### Defining Vector DB Schema

# %%
image_schema = {
    "columns": [
        {"name": "source", "pytype": "str"},
        {"name": "class", "pytype": "str"},
        {
            "name": "embedding",
            "vectorIndex": {"dims": 2048, "metric": "L2", "type": "hnsw"},
        },
    ]
}

# %% [markdown]
# ### Creating Vector DB Table

# %%
# ensure the table does not already exist
try:
    session.table("regnetx064").drop()
    time.sleep(5)
except kdbai.KDBAIException:
    pass

# %%
table = session.create_table("regnetx064", image_schema)

# %% [markdown]
# ### Adding embedded data to the table

# %% [markdown]
# This next stage requires some added steps depending on how large your embedding vector data set is. The "insert" command that will be used in this stage can only insert a certain number of bytes, with a general rule of thumb that 10mb is the maximum amount of data that can be inserted at once.
#
# The following cell will provide a rough estimate of how many megabytes your embedding vector data set is made up of:

# %%
# convert bytes to MB
embedded_df.memory_usage(deep=True).sum() / (1024**2)
# Out:
# 37.92246055603027

# %% [markdown]
# If the data set is comfortably below the 10mb limit, then you should be able to insert the embeddings into the table in one step using the following:

# %%
table.insert(embedded_df)

# %% [markdown]
# Should the data set be larger than 10mb, you will need to divide the data set into smaller parts. This can be done using the following cells.
#
# First of all, it is important to get a rough estimate of how many items will be in each block. This can be done with the following cell:

# %%
megab = embedded_df.memory_usage(deep=True).sum() / (1024**2)
megabs = megab/10
blocks = len(embedded_df)/megabs
math.floor(blocks)
# Out:
# 631

# %% [markdown]
# The previous cell will have provided a rough estimate for an upper limit to the amount of items within each block. The following cell will break the data set into blocks of a specified size. Try this with the estimated block size provided.

# %%
# Yield successive n-sized 
# chunks from l. 
def divide_chunks(l, n): 
      
    # looping till length l 
    for i in range(0, len(l), n):  
        yield l[i:i + n] 
  
# How many elements each 
# list should have 
n = 500

# %%
embedded_df_split = list(divide_chunks(embedded_df, n))

# %% [markdown]
# Now that the data set has been split into smaller blocks, it can be inserted into the KDB.AI table using the following cell:

# %%
for i in range(len(embedded_df_split)):
    table.insert(embedded_df_split[i])
# Out:
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.

# %% [markdown]
# Should you still be returned with an error, try breaking the table into smaller blocks than you are currently using and eventually the blocks will be small enough to be inserted into the table.

# %% [markdown]
# You can now verify that the data has been inserted into the table with the following cell:

# %%
table.query()
# Out:
#                                source    class  \
# 0     data/Healthy/healthy (121).jpeg  Healthy
# 1     data/Healthy/healthy (122).jpeg  Healthy
# 2     data/Healthy/healthy (123).jpeg  Healthy
# 3     data/Healthy/healthy (124).jpeg  Healthy
# 4     data/Healthy/healthy (125).jpeg  Healthy
# ...                               ...      ...
# 2391     data/Yellow/yellow (95).jpeg   Yellow
# 2392     data/Yellow/yellow (96).jpeg   Yellow
# 2393     data/Yellow/yellow (97).jpeg   Yellow
# 2394     data/Yellow/yellow (98).jpeg   Yellow
# 2395     data/Yellow/yellow (99).jpeg   Yellow
#
#                                               embedding
# 0     [0.9535317420959473, 0.038117386400699615, 0.0...
# 1     [0.8989417552947998, 0.06690378487110138, 0.00...
# 2     [0.5552961826324463, 0.3637266755104065, 0.025...
# 3     [0.9178681373596191, 0.03479386866092682, 0.00...
# 4     [0.9047070741653442, 0.036002758890390396, 0.0...
# ...                                                 ...
# 2391  [0.36971867084503174, 0.18064580857753754, 0.0...
# 2392  [0.004562804941087961, 0.011000572703778744, 0...
# 2393  [0.015184606425464153, 0.04275369271636009, 0....
# 2394  [0.0012440424179658294, 0.002134703565388918, ...
# 2395  [0.004850300494581461, 0.00681237131357193, 0....
#
# [2396 rows x 3 columns]

# %% [markdown]
# ## Section 2: Creating Embeddings for Test Image

# %% [markdown]
# Next up, embeddings have to be created for the image that you want to have classified. This will be done in a similar manner to the previous embeddings, but will be classified on the "search" folder rather than the data folder.

# %% [markdown]
# Should you have already created and inserted data into a table in kdb.ai, you can recall it using the following cell. This is useful as you do not need to recreate the embeddings again each time the model is used.

# %%
table = session.table("yourTable")

# %% [markdown]
# ### IMPORTANT

# %% [markdown]
# Data set testing and deletion occurs with the following cell, please backup the images you do not want to lose.

# %%
data_dir = "search/"
image_extensions = [".png", ".jpg", ".jpeg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
            print(f"Deleting {filepath} from data folder")
            os.remove("{filepath}")
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
            print(f"Deleting {filepath} from data folder")
            os.remove("{filepath}")

# %% [markdown]
# ### Loading Search Images

# %%
search_image_paths_map = extract_file_paths_from_folder("search")

# %%
search_dataset = image_dataset_from_directory(
    "search",
    labels="inferred",
    label_mode="categorical",
    shuffle=False,
    seed=1,
    image_size=(224, 224),
    batch_size=1,
)
# Out:
# Found 125 files belonging to 1 classes.

# %% [markdown]
# ### Create Search Embeddings

# %%
search_embeddings = np.empty([len(search_dataset), 2048])
search_labels = np.empty([len(search_dataset), 1])

# %%
# for each image in dataset, get its embedding and class label
for i, image in tqdm(enumerate(search_dataset), total=len(search_dataset)):
    search_embeddings[i, :] = model.predict(image[0], verbose=0)
    search_labels[i, :] = image[1]
# Out:
#   0%|          | 0/125 [00:00<?, ?it/s]

# %% [markdown]
# ### Defining Test Classification Name

# %%
search_classification_types = "test"

# %%
search_class_labels = [search_classification_types for search_label in search_labels]

# %% [markdown]
# ### Defining Image Filepaths

# %%
search_paths = []
for _, image_paths in search_image_paths_map.items():
    search_paths += image_paths

# %%
sorted_search_paths = sorted(search_paths)

# %% [markdown]
# ### Defining Embedding Dataframe

# %%
search_embedded_df = pd.DataFrame(
    {
        "source": sorted_search_paths,
        "class": search_class_labels,
        "embedding": search_embeddings.tolist(),
    }
)

# %% [markdown]
# May need to remove the '.ipynb_checkpoints' here too, so this can be done with the following cell:

# %%
all_paths.remove('data/test/.ipynb_checkpoints')

# %%
show_df(search_embedded_df)
# Out:
# (125, 3)
#                            source class  \
# 0    search/test/healthy (1).jpeg  test
# 1   search/test/healthy (10).jpeg  test
# 2  search/test/healthy (100).jpeg  test
# 3  search/test/healthy (101).jpeg  test
# 4  search/test/healthy (102).jpeg  test
#
#                                            embedding
# 0  [0.6843213438987732, 0.22339944541454315, 0.02...
# 1  [0.3495194613933563, 0.4964156150817871, 0.059...
# 2  [0.3710249960422516, 0.4820334315299988, 0.052...
# 3  [0.548697292804718, 0.21445149183273315, 0.096...
# 4  [0.6019561886787415, 0.35139545798301697, 0.01...

# %% [markdown]
# ## Section 3: Classifying the image

# %%
test_embedding = search_embedded_df.iloc[0,2]

# %%
results_1 = table.search([test_embedding], n=400)

# %%
results_2 = results_1[0]

# %%
statistics.mode(results_2.iloc[:,1])

# %% [markdown]
# ### Alternate: Classifying multiple images

# %% [markdown]
# The following section can be used to classify a list of images rather than just one:

# %%
pd.set_option('display.max_rows', None)

# %%
classifications=[]
for i in range(len(search_embedded_df)):
    w = search_embedded_df.iloc[i,2]
    x = table.search([w], n=400)
    y = x[0]
    z = statistics.mode(y.iloc[:,1])
    classifications.append(z)

# %%
classification_list = pd.DataFrame(
    {
        "source": sorted_search_paths,
        "classification": classifications,
    }
)

# %%
classification_list
# Out:
#                              source classification
# 0      search/test/healthy (1).jpeg        Healthy
# 1     search/test/healthy (10).jpeg        Healthy
# 2    search/test/healthy (100).jpeg        Healthy
# 3    search/test/healthy (101).jpeg        Healthy
# 4    search/test/healthy (102).jpeg        Healthy
# 5    search/test/healthy (103).jpeg        Healthy
# 6    search/test/healthy (104).jpeg        Healthy
# 7    search/test/healthy (105).jpeg        Healthy
# 8    search/test/healthy (106).jpeg        Healthy
# 9    search/test/healthy (107).jpeg        Healthy
# 10   search/test/healthy (108).jpeg        Healthy
# 11   search/test/healthy (109).jpeg        Healthy
# 12    search/test/healthy (11).jpeg        Healthy
# 13   search/test/healthy (110).jpeg        Healthy
# 14   search/test/healthy (111).jpeg        Healthy
# 15   search/test/healthy (112).jpeg        Healthy
# 16   search/test/healthy (113).jpeg        Healthy
# 17   search/test/healthy (114).jpeg        Healthy
# 18   search/test/healthy (115).jpeg        Healthy
# 19   search/test/healthy (116).jpeg        Healthy
# 20   search/test/healthy (117).jpeg        Healthy
# 21   search/test/healthy (118).jpeg        Healthy
# 22   search/test/healthy (119).jpeg        Healthy
# 23    search/test/healthy (12).jpeg        Healthy
# 24   search/test/healthy (120).jpeg        Healthy
# 25      search/test/mosaic (1).jpeg        Healthy
# 26     search/test/mosaic (10).jpeg         Yellow
# 27    search/test/mosaic (100).jpeg         Mosaic
# 28    search/test/mosaic (101).jpeg         Yellow
# 29    search/test/mosaic (102).jpeg         Mosaic
# 30    search/test/mosaic (103).jpeg         Mosaic
# 31    search/test/mosaic (104).jpeg         Mosaic
# 32    search/test/mosaic (105).jpeg         Mosaic
# 33    search/test/mosaic (106).jpeg         Mosaic
# 34    search/test/mosaic (107).jpeg         Mosaic
# 35    search/test/mosaic (108).jpeg         Mosaic
# 36    search/test/mosaic (109).jpeg         Mosaic
# 37     search/test/mosaic (11).jpeg         Mosaic
# 38    search/test/mosaic (110).jpeg         Mosaic
# 39    search/test/mosaic (111).jpeg        Healthy
# 40    search/test/mosaic (112).jpeg         Mosaic
# 41    search/test/mosaic (113).jpeg         Yellow
# 42    search/test/mosaic (114).jpeg        Healthy
# 43    search/test/mosaic (115).jpeg         Mosaic
# 44    search/test/mosaic (116).jpeg        Healthy
# 45    search/test/mosaic (117).jpeg         Mosaic
# 46    search/test/mosaic (118).jpeg         Mosaic
# 47    search/test/mosaic (119).jpeg        Healthy
# 48     search/test/mosaic (12).jpeg         Yellow
# 49    search/test/mosaic (120).jpeg         Mosaic
# 50      search/test/redrot (1).jpeg         RedRot
# 51     search/test/redrot (10).jpeg         RedRot
# 52    search/test/redrot (100).jpeg         RedRot
# 53    search/test/redrot (101).jpeg         RedRot
# 54    search/test/redrot (102).jpeg         RedRot
# 55    search/test/redrot (103).jpeg         RedRot
# 56    search/test/redrot (104).jpeg         RedRot
# 57    search/test/redrot (105).jpeg         RedRot
# 58    search/test/redrot (106).jpeg         RedRot
# 59    search/test/redrot (107).jpeg         RedRot
# 60    search/test/redrot (108).jpeg           Rust
# 61    search/test/redrot (109).jpeg         RedRot
# 62     search/test/redrot (11).jpeg         RedRot
# 63    search/test/redrot (110).jpeg         RedRot
# 64    search/test/redrot (111).jpeg         RedRot
# 65    search/test/redrot (112).jpeg         RedRot
# 66    search/test/redrot (113).jpeg         RedRot
# 67    search/test/redrot (114).jpeg         RedRot
# 68    search/test/redrot (115).jpeg           Rust
# 69    search/test/redrot (116).jpeg         RedRot
# 70    search/test/redrot (117).jpeg         RedRot
# 71    search/test/redrot (118).jpeg         RedRot
# 72    search/test/redrot (119).jpeg         RedRot
# 73     search/test/redrot (12).jpeg           Rust
# 74    search/test/redrot (120).jpeg           Rust
# 75        search/test/rust (1).jpeg           Rust
# 76       search/test/rust (10).jpeg         RedRot
# 77      search/test/rust (100).jpeg           Rust
# 78      search/test/rust (101).jpeg        Healthy
# 79      search/test/rust (102).jpeg           Rust
# 80      search/test/rust (103).jpeg           Rust
# 81      search/test/rust (104).jpeg           Rust
# 82      search/test/rust (105).jpeg           Rust
# 83      search/test/rust (106).jpeg           Rust
# 84      search/test/rust (107).jpeg           Rust
# 85      search/test/rust (108).jpeg           Rust
# 86      search/test/rust (109).jpeg           Rust
# 87       search/test/rust (11).jpeg           Rust
# 88      search/test/rust (110).jpeg           Rust
# 89      search/test/rust (111).jpeg         RedRot
# 90      search/test/rust (112).jpeg           Rust
# 91      search/test/rust (113).jpeg           Rust
# 92      search/test/rust (114).jpeg           Rust
# 93      search/test/rust (115).jpeg           Rust
# 94      search/test/rust (116).jpeg           Rust
# 95      search/test/rust (117).jpeg        Healthy
# 96      search/test/rust (118).jpeg           Rust
# 97      search/test/rust (119).jpeg           Rust
# 98       search/test/rust (12).jpeg         Yellow
# 99      search/test/rust (120).jpeg           Rust
# 100     search/test/yellow (1).jpeg         Yellow
# 101    search/test/yellow (10).jpeg         RedRot
# 102   search/test/yellow (100).jpeg         Yellow
# 103   search/test/yellow (101).jpeg         RedRot
# 104   search/test/yellow (102).jpeg         RedRot
# 105   search/test/yellow (103).jpeg         Yellow
# 106   search/test/yellow (104).jpeg         RedRot
# 107   search/test/yellow (105).jpeg         Yellow
# 108   search/test/yellow (106).jpeg         Yellow
# 109   search/test/yellow (107).jpeg         Yellow
# 110   search/test/yellow (108).jpeg         Yellow
# 111   search/test/yellow (109).jpeg         Yellow
# 112    search/test/yellow (11).jpeg         RedRot
# 113   search/test/yellow (110).jpeg         Yellow
# 114   search/test/yellow (111).jpeg         RedRot
# 115   search/test/yellow (112).jpeg         Yellow
# 116   search/test/yellow (113).jpeg         RedRot
# 117   search/test/yellow (114).jpeg         Yellow
# 118   search/test/yellow (115).jpeg         Yellow
# 119   search/test/yellow (116).jpeg         Yellow
# 120   search/test/yellow (117).jpeg         Yellow
# 121   search/test/yellow (118).jpeg         Yellow
# 122   search/test/yellow (119).jpeg         Yellow
# 123    search/test/yellow (12).jpeg         Yellow
# 124   search/test/yellow (120).jpeg        Healthy
