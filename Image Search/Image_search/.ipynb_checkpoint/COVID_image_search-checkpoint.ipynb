# %% [markdown]
# # Image Search on Brain MRI Scans
#
# This example demonstrates how to store [brain scan images](https://www.kaggle.com/datasets/sartajbhuvaji/brain-tumor-classification-mri) as vector embeddings in KDB.AI, then how to search this dataset to instantly retrieve similar images.
#
# Brain tumors are intricate due to variations in size and location, therefore understanding their nature is challenging. Professional neurosurgeons are essential for accurate MRI analysis, but in developing nations, the scarcity of skilled doctors and tumor knowledge results in time-consuming report generation from MRI scans.
#
# A potential solution lies in automated systems like vector database search, which could help alleviate this issue. Using semantic search, KDB.AI enables users to effectively retrieve the most similar scan images quickly even when the query and database content aren't an exact match, leveraging semantic context.
#
# ### Aim
# In this tutorial, we'll walk through the process of storing images in a vector database, using a pre-trained neural network to generate data structures known as vector embeddings. We will use KDB.AI's vector database offering to find images with similar vector embeddings to an input query image. We will cover the following topics:
#
# 1. Load Image Data
# 1. Create Image Vector Embeddings
# 1. Store Embeddings in KDB.AI
# 1. Query the KDB.AI Table
# 1. Search For Similar Images To A Target Image
# 1. Delete the KDB.AI Table
#
# ---

# %% [markdown]
# ## 0. Setup

# %% [markdown]
# ### Install dependencies
#
# In order to successfully run this sample, the [Setup](https://github.com/KxSystems/kdbai-samples/blob/main/README.md#setup) steps in the repository's `README.md` file must be completed.
# This will ensure that you have installed all of the relevant packages and versions needed for this sample.
# If you have not completed these setup steps, please navigate to the repositories `README.md` file and follow the steps detailed there.

# %% [markdown]
# ### Set Environment Variables

# %%
import os

# %%
### ignore tensorflow warnings
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# %%
# force tensorflow to use CPU only
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %% [markdown]
# ### Import Packages

# %%
# download data
from zipfile import ZipFile

# %%
# embeddings
from tensorflow.keras.utils import image_dataset_from_directory
import tensorflow as tf
from huggingface_hub import from_pretrained_keras
from PIL import Image
import numpy as np
import pandas as pd

# %%
# timing
from tqdm.auto import tqdm

# %%
# vector DB
import kdbai_client as kdbai
from getpass import getpass
import time

# %%
# plotting
import umap.umap_ as umap
from matplotlib import pyplot as plt

# %% [markdown]
# ### Define Helper Functions

# %%
def show_df(df: pd.DataFrame) -> pd.DataFrame:
    print(df.shape)
    return df.head()

# %%
def plot_image(axis, source: str, label=None) -> None:
    axis.imshow(plt.imread(source), cmap = 'gray')
    axis.axis("off")
    title = (f"{label}: " if label else "") + source.split("/")[-1]
    axis.set_title(title)

# %% [markdown]
# ## 1. Load Image Data

# %% [markdown]
# ### Dataset Overview
#
# The dataset that will be used in this sample is the [Brain Tumor Classification images taken from Kaggle](https://www.kaggle.com/datasets/sartajbhuvaji/brain-tumor-classification-mri).
# The dataset consists of MRI brain scan images organized into four classes based on the presence of a tumor in the image: glioma, melignioma, pituitary, and no tumor.
#
# The original Kaggle dataset contains two folders a `Training` folder and a `Testing` folder, both of which contain images organized by these tumor class.
# As a pre-processing step, we have resized the original images to be of dimensions (224, 224, 3) with the height & width being 224 and there being 3 dimensions for the Red, Green, and Blue pixel intensity.
# We have also renamed each image corresponding to its class and given each one a unique ID within its directory.
#
# Post processing, the `Training` folder in this original dataset was used to train the ResNet model which we use to create the embeddings in this notebook.
# The post processed `Testing` folder has been renamed to `data` and will be what we use in this notebook.
# This data has not been seen by our ResNet model and will help to avoid any overfitting when it comes to creating the vector embeddings.

# %% [markdown]
# ### Define List Of Paths To The Extracted Image Files
#
# Next, let's extract image file paths from different subfolders within the 'Testing' directory. These are needed to pass to our function in the next section to create embeddings.

# %%
def extract_file_paths_from_folder(parent_dir: str) -> dict:
    image_paths = {}
    for sub_folder in os.listdir(parent_dir):
        sub_dir = os.path.join(parent_dir, sub_folder)
        image_paths[sub_folder] = [
            os.path.join(sub_dir, file) for file in os.listdir(sub_dir)
        ]
    return image_paths

# %%
image_paths_map = extract_file_paths_from_folder("COVID-images")

# %% [markdown]
# Lets take a look at some example images from each category. The images are numbered, so we can choose a number between 0 and 73 and fetch that image from each folder:

# %% [markdown]
# ### Visualize Some Of The Images

# %% [markdown]
# We can then plot each of our demo images using the `plot_image()` helper function:

# %%
image_index = 20  # feel free to change this!

# %%
# create subplots
_, ax = plt.subplots(nrows=len(image_paths_map) // 2, ncols=2, figsize=(10, 8))
axes = ax.reshape(-1)

# get image at specified index
for i, (_, image_paths) in enumerate(image_paths_map.items()):
    for path in image_paths:
        if path.endswith(f"{image_index}.png"):
            break

    # plot each image in subplots
    plot_image(axes[i], path)

# %% [markdown]
# ### Load data using `image_dataset_from_directory()`

# %% [markdown]
# The `image_dataset_from_directory()` function saves each image with a class label corresponding to the image's directory. This is a quick and easy way to get our data and its labels in the right format for embedding.

# %%
dataset = image_dataset_from_directory(
    "COVID-images",
    labels="inferred",
    label_mode="categorical",
    shuffle=False,
    seed=1,
    image_size=(299, 299),
    batch_size=1,
)
# Out:
# Found 6351 files belonging to 4 classes.

# %% [markdown]
# ## 2. Create Image Vector Embeddings

# %% [markdown]
# To create our image embeddings, we will use a neural network that has been pre-trained on the brain tumor classification problem. In this example, we will use a network containing a ResNet-50 backbone. ResNet-50 is a popular neural network architecture for general image classification tasks.
#
# ResNet-50 was originally trained on the ImageNet dataset - although this dataset contains millions of images, including of MRI scans, it does not contain examples of different brain tumor images. Therefore, our custom model was created by taking ResNet-50, pre-trained on ImageNet, and re-training it to classify MRI brain scan images.
#
# This is an example of Transfer Learning - we are taking a model that has been pre-trained for a task (ResNet-50 for ImageNet classification) and using it as a starting point to solve a more specific problem (classify MRI brain scan images).s.

# %% [markdown]
# ### Load Pre-Trained Classification Neural Network

# %%
model = tf.keras.models.load_model('saved_model/lungs_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 305, 305,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 150, 150,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 150, 150,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 150, 150,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 152, 152,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 75, 75,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 75, 75,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 75, 75,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 75, 75,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 75, 75,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 75, 75,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 75, 75,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 75, 75,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 75, 75,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 75, 75,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 75, 75,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 75, 75,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 75, 75,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 75, 75,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 75, 75,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 75, 75,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 75, 75,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 75, 75,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 75, 75,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 75, 75,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 75, 75,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 75, 75,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 75, 75,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 75, 75,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 75, 75,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 75, 75,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 75, 75,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 75, 75,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 75, 75,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 75, 75,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 75, 75,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 75, 75,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 75, 75,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 38, 38,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 38, 38,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 38, 38,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 38, 38,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 38, 38,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 38, 38,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 38, 38,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 38, 38,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 38, 38,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 38, 38,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 38, 38,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 38, 38,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 38, 38,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 38, 38,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 38, 38,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 38, 38,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 38, 38,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 38, 38,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 38, 38,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 38, 38,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 38, 38,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 38, 38,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 38, 38,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 38, 38,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 38, 38,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 38, 38,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 38, 38,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 38, 38,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 38, 38,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 38, 38,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 38, 38,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 38, 38,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 38, 38,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 38, 38,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 38, 38,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 38, 38,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 38, 38,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 38, 38,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 38, 38,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 38, 38,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 38, 38,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 38, 38,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 19, 19,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 19, 19,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 19, 19,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 19, 19,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 19, 19,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 19, 19,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 19, 19,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 19, 19,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 19, 19,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 19, 19,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 19, 19,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 19, 19,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 19, 19,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 19, 19,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 19, 19,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 19, 19,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 19, 19,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 19, 19,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 19, 19,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 19, 19,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 19, 19,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 19, 19,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 19, 19,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 19, 19,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 19, 19,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 19, 19,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 19, 19,    │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 10, 10,    │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 10, 10,    │          0 │ conv5_block1_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 10, 10,    │          0 │ conv5_block1_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 10, 10,    │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 10, 10,    │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 10, 10,    │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 10, 10,    │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 10, 10,    │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 10, 10,    │          0 │ conv5_block2_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 10, 10,    │          0 │ conv5_block2_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 10, 10,    │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 10, 10,    │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 10, 10,    │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 10, 10,    │          0 │ conv5_block3_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 10, 10,    │          0 │ conv5_block3_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 10, 10,    │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 10, 10,    │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ conv5_block3_out… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 2048)      │          0 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 2048)      │          0 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 2048)      │          0 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 2048)      │  4,196,352 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 27,784,066 (105.99 MB)
#  Trainable params: 27,730,944 (105.79 MB)
#  Non-trainable params: 53,120 (207.50 KB)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# We can see that the model has four layers: ResNet-50, Flatten, and two Dense layers. The ResNet-50 "layer" is really many layers, abstracted under one name. This is why it contains millions of parameters. The Flatten layer does not contain any parameters - its sole purpose is to "flatten" the outputs of ResNet-50 into a 2048-dimensional vector, known as a feature vector. The final two Dense layers transform the ResNet-50 feature vector into a 4-dimensional classification of the input image.

# %% [markdown]
# ### Transform Classification Network Into Embedding Network

# %% [markdown]
# For a better understanding of the `model.summary()`, here is a diagram representation of the network:

# %% [markdown]
# ![mri-network-diagram](images/mri_network_diagram.png)

# %% [markdown]
# Although the Dense layers were essential for training ResNet-50 to classify our four brain tumor classes, we will no longer be needing them. In this example, we are interested in the embedding, not the classification output. Therefore, we will remove the last two layers of the pre-trained model by calling `pop()`. This means that the new output of the model is the 2048-dimensional feature vector - the ResNet-50 embedding of the input image.

# %%
model.pop()
model.pop()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
# =================================================================
# Total params: 23587712 (89.98 MB)
# Trainable params: 23534592 (89.78 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________

# %% [markdown]
# ### Use Embedding Network To Create Image Embeddings

# %% [markdown]
# ##### Generate Embeddings
#
# To generate the image embeddings, we will iterate through the dataset, get the 2048-dimension embedding by calling `model.predict()` on the image, and save the corresponding class vector.

# %%
# create empty arrays to store the embeddings and labels
embeddings = np.empty([len(dataset), 2048])
labels = np.empty([len(dataset), 4])

# %%
# for each image in dataset, get its embedding and class label
for i, image in tqdm(enumerate(dataset), total=len(dataset)):
    embeddings[i, :] = model.predict(image[0], verbose=0)
    labels[i, :] = image[1]
# Out:
#   0%|          | 0/6351 [00:00<?, ?it/s]

# %% [markdown]
# ##### Define Class Labels
#
# Now we have the class labels, we can get the tumor types by checking which index in the vector is equal to 1.

# %%
# list the tumor types in sorted order
tumor_types = sorted(image_paths_map.keys())

# %%
# for each vector, save the tumor type given by the high index
class_labels = [tumor_types[label.argmax()] for label in labels]

# %% [markdown]
# ##### Define Image File Paths
#
# It is often useful to save the entire filepath of the image, rather than just its name. In the cell below, we iterate through the files and save their filepaths.

# %%
# get a single list of all paths
all_paths = []
for _, image_paths in image_paths_map.items():
    all_paths += image_paths

# %%
# sort the source_files in alphanumeric order
sorted_all_paths = sorted(all_paths)

# %% [markdown]
# ##### Define Embedding DataFrame
#
# Now we have all of our components: the image filepath, the image class, and the vector embedding. The next step is to put it all in a DataFrame for insertion to KDBAI.

# %%
embedded_df = pd.DataFrame(
    {
        "source": sorted_all_paths,
        "class": class_labels,
        "embedding": embeddings.tolist(),
    }
)

# %%
show_df(embedded_df)
# Out:
# (6351, 3)
#                               source  class  \
# 0     COVID-images/COVID/COVID-1.png  COVID
# 1  COVID-images/COVID/COVID-1003.png  COVID
# 2  COVID-images/COVID/COVID-1006.png  COVID
# 3  COVID-images/COVID/COVID-1008.png  COVID
# 4  COVID-images/COVID/COVID-1013.png  COVID
#
#                                            embedding
# 0  [0.1930886059999466, 0.7402693033218384, 0.066...
# 1  [0.03127330541610718, 0.014013336971402168, 0....
# 2  [0.4907979667186737, 0.06655334681272507, 0.44...
# 3  [0.9774723649024963, 0.015101766213774681, 0.0...
# 4  [0.32300350069999695, 0.11843094229698181, 0.5...

# %% [markdown]
# ### Visualising The Embeddings

# %% [markdown]
# It is often challenging to comprehend how feature embeddings are able to organize and cluster data because of their high dimensionality.
# One trick is to use UMAP: a technique which reduces the number of dimensions to allow us to visualize the clustering in 2D.
# This will give us a better idea of the success of the classification network, as well as some insight into where possible mis-classifications may occur.
#
# ##### Use UMAP To Reduce The Embeddings To Two Dimensions

# %%
_umap = umap.UMAP(n_neighbors=15, min_dist=0.0)

# %%
umap_df = pd.DataFrame(_umap.fit_transform(embeddings), columns=["u0", "u1"])

# %%
show_df(umap_df)
# Out:
# (6351, 2)
#           u0         u1
# 0  12.775760  14.489168
# 1  -9.252674  11.752310
# 2  11.479973   3.952389
# 3  16.199232   4.404384
# 4   6.917882   5.268443

# %% [markdown]
# ##### Visualise UMAP Dimensions
#
# Now we will plot the Embeddings in 2D, with each class shown in a different color:

# %%
# define color for each class label
class_colors = ["blue", "red", "green", "purple"]

# %%
# Create a figure for plotting
plt.figure(figsize=(10, 8))

# Scatter plot with 'u0' and 'u1' columns as x and y, color mapped by class_labels
for tumor_type, color in zip(tumor_types, class_colors):
    indices_to_plot = [i for i, label in enumerate(class_labels) if label == tumor_type]
    subset = umap_df.iloc[indices_to_plot]
    plt.scatter(subset["u0"], subset["u1"], label=tumor_type, color=color, alpha=0.5)

# beutify plot
plt.title("Embeddings Map for X-ray Lung Scan Images")
plt.legend()
plt.show()

# %% [markdown]
# As shown above, the network is able to separate most of the data between classes, but there is still some overlap, especially with the glioma class (shown in blue). However, for the vast majority of points on the graph, their "nearest neighbors" belong to the same class as them. Therefore, when conducting vector similarity search using the embeddings, the majority of our results should be from the same class.

# %% [markdown]
# ## 3. Store Embeddings in KDB.AI

# %% [markdown]
# ##### Option 2. KDB.AI Server
#
# To use KDB.AI Server, you will need download and run your own container.
# To do this, you will first need to sign up for free [here](https://trykdb.kx.com/kdbaiserver/signup/).
#
# You will receive an email with the required license file and bearer token needed to download your instance.
# Follow instructions in the signup email to get your session up and running.
#
# Once the [setup steps](https://code.kx.com/kdbai/gettingStarted/kdb-ai-server-setup.html) are complete you can then connect to your KDB.AI Server session using `kdbai.Session` and passing your local endpoint.

# %%
session = kdbai.Session(endpoint="http://localhost:8082")

# %% [markdown]
# ### Define Vector DB Table Schema
#
# The next step is to define a schema for our KDB.AI table where we will store our embeddings. Our table will contain three columns, identical to those in our embeddings DataFrame:
# 1. `source`: filepath to the raw image file
# 2. `class`: tumor class label
# 3. `embedding`: 2048-dimension feature vectors for similarity search

# %%
image_schema_l2_hnsw = {
    "columns": [
        {"name": "source", "pytype": "str"},
        {"name": "class", "pytype": "str"},
        {
            "name": "embedding",
            "vectorIndex": {"dims": 2048, "metric": "L2", "type": "hnsw"},
        },
    ]
}
image_schema_ip_hnsw = {
    "columns": [
        {"name": "source", "pytype": "str"},
        {"name": "class", "pytype": "str"},
        {
            "name": "embedding",
            "vectorIndex": {"dims": 2048, "metric": "IP", "type": "hnsw"},
        },
    ]
}
image_schema_cs_hnsw = {
    "columns": [
        {"name": "source", "pytype": "str"},
        {"name": "class", "pytype": "str"},
        {
            "name": "embedding",
            "vectorIndex": {"dims": 2048, "metric": "CS", "type": "hnsw"},
        },
    ]
}
image_schema_l2_flat = {
    "columns": [
        {"name": "source", "pytype": "str"},
        {"name": "class", "pytype": "str"},
        {
            "name": "embedding",
            "vectorIndex": {"dims": 2048, "metric": "L2", "type": "flat"},
        },
    ]
}
image_schema_ip_flat = {
    "columns": [
        {"name": "source", "pytype": "str"},
        {"name": "class", "pytype": "str"},
        {
            "name": "embedding",
            "vectorIndex": {"dims": 2048, "metric": "IP", "type": "flat"},
        },
    ]
}
image_schema_cs_flat = {
    "columns": [
        {"name": "source", "pytype": "str"},
        {"name": "class", "pytype": "str"},
        {
            "name": "embedding",
            "vectorIndex": {"dims": 2048, "metric": "CS", "type": "flat"},
        },
    ]
}

# %%
image_schema_l2_ivfpq = {
    "columns": [
        {"name": "source", "pytype": "str"},
        {"name": "class", "pytype": "str"},
        {
            "name": "embedding",
            "vectorIndex": {"metric": "L2", "type": "ivfpq", "trainingVectors":1000, "nbits":4},
        },
    ]
}
image_schema_ip_ivfpq = {
    "columns": [
        {"name": "source", "pytype": "str"},
        {"name": "class", "pytype": "str"},
        {
            "name": "embedding",
            "vectorIndex": {"metric": "IP", "type": "ivfpq", "trainingVectors":1000, "nbits":4},
        },
    ]
}

# %% [markdown]
# ### Crate Vector DB Table
#
# We then use the KDB.AI `create_table()` function to create a table that matches the defined schema in the vector database.

# %%
# ensure the table does not already exist
try:
    session.table("lungs_l2_hnsw").drop()
    session.table("lungs_ip_hnsw").drop()
    session.table("lungs_cs_hnsw").drop()
    session.table("lungs_l2_flat").drop()
    session.table("lungs_ip_flat").drop()
    session.table("lungs_cs_flat").drop()
    time.sleep(5)
except kdbai.KDBAIException:
    pass

# %%
try:
    session.table("lungs_l2_ivfpq").drop()
    session.table("lungs_ip_ivfpq").drop()
    time.sleep(5)
except kdbai.KDBAIException:
    pass

# %%
table_l2_hnsw = session.create_table("lungs_l2_hnsw", image_schema_l2_hnsw)
table_ip_hnsw = session.create_table("lungs_ip_hnsw", image_schema_ip_hnsw)
table_cs_hnsw = session.create_table("lungs_cs_hnsw", image_schema_cs_hnsw)
table_l2_flat = session.create_table("lungs_l2_flat", image_schema_l2_flat)
table_ip_flat = session.create_table("lungs_ip_flat", image_schema_ip_flat)
table_cs_flat = session.create_table("lungs_cs_flat", image_schema_cs_flat)

# %%
table_l2_ivfpq = session.create_table("lungs_l2_ivfpq", image_schema_l2_ivfpq)
table_ip_ivfpq = session.create_table("lungs_ip_ivfpq", image_schema_ip_ivfpq)

# %%
embedded_df[5947:6197]

# %% [markdown]
# ### Add Embedded Data to KDB.AI Table
#
# It is a good idea to check the memory usage of our data before inserting in to KDB.AI.

# %%
# convert bytes to MB
embedded_df.memory_usage(deep=True).sum() / (1024**2)
# Out:
# 100.59794807434082

# %% [markdown]
# This dataset contains only 6MB, so we can insert all the data at once. For bigger image datasets, we should split the data into batches and insert <10MB at a time.

# %%
#training data for ivfpq schemas
#embedded_df[:250] #COVID
#embedded_df[1085:1335] #Lung Opacity
#embedded_df[2889:3139] #Normal
#embedded_df[5947:6197] #Viral Pnuemonia
traindata = pd.concat([embedded_df[:250],embedded_df[1085:1335],embedded_df[2889:3139],embedded_df[5947:6197]])
nontraindata = pd.concat([embedded_df[250:1085],embedded_df[1335:2889],embedded_df[3139:5947],embedded_df[6197:]])
print(len(embedded_df))
print(traindata.memory_usage(deep=True).sum() / (1024**2))
print(len(traindata))
print(nontraindata.memory_usage(deep=True).sum() / (1024**2))
print(len(nontraindata))
# Out:
# 6351
# 15.851316452026367
# 1000
# 84.79496383666992
# 5351

# %%
#Yield successive n-sized chunks from l.  
def divide_chunks(l, n):  
   # looping till length l  
    for i in range(0, len(l), n):   
        yield l[i:i + n]  
 
# How many elements each list should have  
n = len(embedded_df) // 12  

#You can then split up your dataset using the following line: 
embedded_df_split = list(divide_chunks(embedded_df, n)) 

#and then you can insert this into the table using: 
for i in range(len(embedded_df_split)): 
    table_l2_hnsw.insert(embedded_df_split[i]) 
    table_ip_hnsw.insert(embedded_df_split[i]) 
    table_cs_hnsw.insert(embedded_df_split[i]) 
    table_l2_flat.insert(embedded_df_split[i]) 
    table_ip_flat.insert(embedded_df_split[i]) 
    table_cs_flat.insert(embedded_df_split[i])
# Out:
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.

# %%
table_l2_ivfpq.schema()
#ratio trainingVectors/2 xexp nbits
# Out:
# {'columns': [{'name': 'source', 'qtype': 'symbol', 'pytype': 'str'},
#   {'name': 'class', 'qtype': 'symbol', 'pytype': 'str'},
#   {'name': 'embedding',
#    'vectorIndex': {'metric': 'L2',
#     'type': 'ivfpq',
#     'trainingVectors': 1000,
#     'nbits': 4},
#    'qtype': 'reals',
#    'pytype': 'float32'}]}

# %%
m = len(nontraindata) // 10
embedded_df_split_ivf = list(divide_chunks(nontraindata, m))
#train ivfpq datasets
table_l2_ivfpq.train(traindata[:500])
table_l2_ivfpq.train(traindata[500:])

#for i in range(len(embedded_df_split_ivf)):
#    table_l2_ivfpq.insert(embedded_df_split_ivf[i])
#    table_ip_ivfpq.insert(embedded_df_split_ivf[i])
# Out:
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# 'Index training complete, 0 extra rows discarded'

# %%
table_ip_ivfpq.train(traindata[:500])
table_ip_ivfpq.train(traindata[500:])

# %% [markdown]
# ### Verify Data Has Been Inserted
#
# Running `table.query()` should show us that data has been added.

# %%
for i in range(len(embedded_df_split_ivf)):
    table_l2_ivfpq.insert(embedded_df_split_ivf[i])
    table_ip_ivfpq.insert(embedded_df_split_ivf[i])
# Out:
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.
# WARNING:root:`data` DataFrame has a non trivial index. It will be dropped before insertion.

# %%
table_l2_ivfpq.query()
# Out:
#                                                  source            class  \
# 0                     COVID-images/COVID/COVID-1798.png            COVID
# 1                     COVID-images/COVID/COVID-1805.png            COVID
# 2                     COVID-images/COVID/COVID-1814.png            COVID
# 3                     COVID-images/COVID/COVID-1815.png            COVID
# 4                     COVID-images/COVID/COVID-1817.png            COVID
# ...                                                 ...              ...
# 5346  COVID-images/Viral_Pneumonia/Viral Pneumonia-9...  Viral_Pneumonia
# 5347  COVID-images/Viral_Pneumonia/Viral Pneumonia-9...  Viral_Pneumonia
# 5348  COVID-images/Viral_Pneumonia/Viral Pneumonia-9...  Viral_Pneumonia
# 5349  COVID-images/Viral_Pneumonia/Viral Pneumonia-9...  Viral_Pneumonia
# 5350  COVID-images/Viral_Pneumonia/Viral Pneumonia-9...  Viral_Pneumonia
#
#                                               embedding
# 0     [0.10137610137462616, 0.036933254450559616, 0....
# 1     [0.6492176651954651, 0.07765069603919983, 0.27...
# 2     [0.11333873122930527, 0.6580268740653992, 0.22...
# 3     [0.379459410905838, 0.3109845817089081, 0.3027...
# 4     [0.7515739798545837, 0.1189173012971878, 0.129...
# ...                                                 ...
# 5346  [1.4559446753992233e-05, 1.8509032088331878e-0...
# 5347  [4.3969259422738105e-05, 1.5448327758349478e-0...
# 5348  [0.009182139299809933, 0.0017427902203053236, ...
# 5349  [2.2270078261499293e-05, 0.0003343209391459822...
# 5350  [0.06125681474804878, 0.024947458878159523, 0....
#
# [5351 rows x 3 columns]

# %%
table_l2_hnsw.query()
# Out:
#                                                  source            class  \
# 0                        COVID-images/COVID/COVID-1.png            COVID
# 1                     COVID-images/COVID/COVID-1003.png            COVID
# 2                     COVID-images/COVID/COVID-1006.png            COVID
# 3                     COVID-images/COVID/COVID-1008.png            COVID
# 4                     COVID-images/COVID/COVID-1013.png            COVID
# ...                                                 ...              ...
# 6346  COVID-images/Viral_Pneumonia/Viral Pneumonia-9...  Viral_Pneumonia
# 6347  COVID-images/Viral_Pneumonia/Viral Pneumonia-9...  Viral_Pneumonia
# 6348  COVID-images/Viral_Pneumonia/Viral Pneumonia-9...  Viral_Pneumonia
# 6349  COVID-images/Viral_Pneumonia/Viral Pneumonia-9...  Viral_Pneumonia
# 6350  COVID-images/Viral_Pneumonia/Viral Pneumonia-9...  Viral_Pneumonia
#
#                                               embedding
# 0     [0.1930886059999466, 0.7402693033218384, 0.066...
# 1     [0.03127330541610718, 0.014013336971402168, 0....
# 2     [0.4907979667186737, 0.06655334681272507, 0.44...
# 3     [0.9774723649024963, 0.015101766213774681, 0.0...
# 4     [0.32300350069999695, 0.11843094229698181, 0.5...
# ...                                                 ...
# 6346  [1.4559446753992233e-05, 1.8509032088331878e-0...
# 6347  [4.3969259422738105e-05, 1.5448327758349478e-0...
# 6348  [0.009182139299809933, 0.0017427902203053236, ...
# 6349  [2.2270078261499293e-05, 0.0003343209391459822...
# 6350  [0.06125681474804878, 0.024947458878159523, 0....
#
# [6351 rows x 3 columns]

# %% [markdown]
# ## 4. Query KDB.AI Table

# %% [markdown]
# Now that all the embeddings of the images are in KDB.AI's database, it's time to demonstrate KDB.AI's fast query capabilities.
#
# The `query` function accepts a wide range of arguments to make it easy to filter, aggregate, and sort.
# Run `?table.query` to see them all.
#
# Let's demonstrate this by filtering for images that contain "glioma" in the filename.

# %%
table_l2_hnsw.query(filter=[("like", "class", "*Lung*")])
# Out:
#                                                source         class  \
# 0        COVID-images/Lung_Opacity/Lung_Opacity-1.png  Lung_Opacity
# 1       COVID-images/Lung_Opacity/Lung_Opacity-10.png  Lung_Opacity
# 2     COVID-images/Lung_Opacity/Lung_Opacity-1009.png  Lung_Opacity
# 3      COVID-images/Lung_Opacity/Lung_Opacity-101.png  Lung_Opacity
# 4     COVID-images/Lung_Opacity/Lung_Opacity-1013.png  Lung_Opacity
# ...                                               ...           ...
# 1799   COVID-images/Lung_Opacity/Lung_Opacity-984.png  Lung_Opacity
# 1800   COVID-images/Lung_Opacity/Lung_Opacity-985.png  Lung_Opacity
# 1801   COVID-images/Lung_Opacity/Lung_Opacity-986.png  Lung_Opacity
# 1802   COVID-images/Lung_Opacity/Lung_Opacity-994.png  Lung_Opacity
# 1803   COVID-images/Lung_Opacity/Lung_Opacity-997.png  Lung_Opacity
#
#                                               embedding
# 0     [0.11273650079965591, 0.42313218116760254, 0.4...
# 1     [0.17577897012233734, 0.7366110682487488, 0.08...
# 2     [0.04618028178811073, 0.7661265730857849, 0.18...
# 3     [0.053287386894226074, 0.9310305118560791, 0.0...
# 4     [0.10065077245235443, 0.7487967014312744, 0.15...
# ...                                                 ...
# 1799  [0.004457301925867796, 0.9920989274978638, 0.0...
# 1800  [0.0596608929336071, 0.6163009405136108, 0.324...
# 1801  [0.06715655326843262, 0.8165585398674011, 0.11...
# 1802  [0.00641989940777421, 0.9740433096885681, 0.01...
# 1803  [0.048398327082395554, 0.9246647953987122, 0.0...
#
# [1804 rows x 3 columns]

# %% [markdown]
# ## 5. Search For Similar Images To A Target Image

# %% [markdown]
# Finally, let's perform similarity search on the images. We do this using the `table.search()` function.

# %% [markdown]
# ### Choose Example Image
#
# First let's select a random row from our test dataset and plot the image.

# %%
# Get a sample row
random_row_index_1 = 40

# %%
# Select the random row and the desired column's value
random_row_1 = embedded_df.iloc[random_row_index_1]

# %%
plot_image(plt.subplots()[-1], random_row_1["source"], label="Query Image")

# %% [markdown]
# We will save the embedding for this image in the `sample embedding` variable.

# %%
sample_embedding_1 = random_row_1["embedding"]

# %% [markdown]
# ### Search Based On The Chosen Image
#
# Using the the embeddings we extracted above in `sample_embedding` for this random image, we can call `table.search()` to find the `8` nearest neighbors to our query image.
#
# In a real life scenario, the sample images used to search would be ones selected by a doctor.

# %%
results_1 = table_l2_hnsw.search([sample_embedding_1], n=9)
results_1[0]
# Out:
#                                 source   class  \
# 0    COVID-images/COVID/COVID-1116.png   COVID
# 1  COVID-images/Normal/Normal-4760.png  Normal
# 2  COVID-images/Normal/Normal-5271.png  Normal
# 3  COVID-images/Normal/Normal-5508.png  Normal
# 4    COVID-images/COVID/COVID-2462.png   COVID
# 5  COVID-images/Normal/Normal-3057.png  Normal
# 6  COVID-images/Normal/Normal-4717.png  Normal
# 7  COVID-images/Normal/Normal-8473.png  Normal
# 8    COVID-images/COVID/COVID-1856.png   COVID
#
#                                            embedding  __nn_distance
# 0  [0.22551202774047852, 0.0548495352268219, 0.71...       0.000000
# 1  [0.22440436482429504, 0.05457346513867378, 0.7...       0.000003
# 2  [0.22341395914554596, 0.05495133250951767, 0.7...       0.000007
# 3  [0.21963152289390564, 0.057852428406476974, 0....       0.000048
# 4  [0.2324455976486206, 0.05117041617631912, 0.71...       0.000072
# 5  [0.2316543459892273, 0.04877733439207077, 0.71...       0.000075
# 6  [0.22494880855083466, 0.06120821833610535, 0.7...       0.000076
# 7  [0.21811936795711517, 0.052874643355607986, 0....       0.000135
# 8  [0.2218785434961319, 0.04812327399849892, 0.72...       0.000164

# %% [markdown]
# The results returned from `table.search()` show the closest matches along with value of nearest neighbor distances `__nn_distance`.
# Since our query vector is taken from this dataset, the "nearest neighbour" will be the query image itself, with a `__nn_distance` of zero.
# As a result, to get the 8 nearest neighbours, we had to select the 9 most similar vectors to our vector.

# %% [markdown]
# ### Plot Most Similar Images
#
# Let's visualize these images.
# The function `plot_test_result_with_8NN()` will plot our query image alongside its 8 nearest neighbours.
# Before calling this function, will exclude the point itself.

# %%
def plot_test_result_with_8NN(test_file: str, neighbors: pd.Series) -> None:
    # create figure
    _, ax = plt.subplots(nrows=3, ncols=3, figsize=(12, 7))
    axes = ax.reshape(-1)

    # plot query image
    plot_image(axes[0], test_file, "Test")

    # plot nearest neighbors
    for i, (_, value) in enumerate(neighbors.items(), start=1):
        plot_image(axes[i], value, f"{i}-NN")

# %%
nn1_filenames = results_1[0][1:]["source"]

# %%
plot_test_result_with_8NN(random_row_1["source"], nn1_filenames)

# %% [markdown]
# We can see that the images returned are similar in nature to the test image.

# %% [markdown]
# ### Automate This Search Process

# %%
def mri_image_nn_search(table, df: pd.DataFrame, row_index: int) -> None:
    # Select the random row and the desired column's value
    row = df.iloc[row_index]

    # get the embedding from this row
    row_embedding = row["embedding"]

    # search for 8 nearest neighbors (exclude self)
    nn_results = table.search([row_embedding], n=9)[0][1:]

    # plot the neighbors
    plot_test_result_with_8NN(row["source"], nn_results["source"])

# %% [markdown]
# Let's try another sample image and search for similar images.

# %%
# Get another row
random_row_index_2 = np.random.randint(0,len(embedded_df))
print(random_row_index_2)
# Out:
# 3462

# %%
mri_image_nn_search(table_l2_hnsw, embedded_df, random_row_index_2)

# %% [markdown]
# We can see with this second test image that we get a set of similar brain scans back that match the second test image closely and are all in the same category. This kind of result can help a doctor confirm their own assumptions.

# %%
 def accuracy_measure (table, df: pd.DataFrame) -> None: 
    full_accuracy = 0 
    for i in tqdm(range(6351)):
        row = df.iloc[i] 
        embed = row["embedding"] 
        neighbors = table.search([embed],n=9)[0][1:] 
        accuracy = 0 
        for j,category in enumerate(neighbors["class"]): 
            if category == row["class"]: 
                accuracy += (8-j) 
        accuracy = accuracy/36 
        full_accuracy += accuracy 
    full_accuracy = full_accuracy/6351 
    print(full_accuracy) 

def accuracy_measure_ivf (table, df: pd.DataFrame) -> None: 
    full_accuracy = 0 
    for i in tqdm(range(5351)):
        row = df.iloc[i] 
        embed = row["embedding"] 
        neighbors = table.search([embed],n=9)[0][1:] 
        accuracy = 0 
        for j,category in enumerate(neighbors["class"]): 
            if category == row["class"]: 
                accuracy += (8-j) 
        accuracy = accuracy/36 
        full_accuracy += accuracy 
    full_accuracy = full_accuracy/5351 
    print(full_accuracy)

# %%
accuracy_measure(table_l2_hnsw, embedded_df)
# Out:
#   0%|          | 0/6351 [00:00<?, ?it/s]
# 0.7622202977658816

# %%
accuracy_measure(table_ip_hnsw, embedded_df)
# Out:
#   0%|          | 0/6351 [00:00<?, ?it/s]
# 0.798780594482059

# %%
accuracy_measure(table_cs_hnsw, embedded_df)
# Out:
#   0%|          | 0/6351 [00:00<?, ?it/s]
# 0.7619447506079511

# %%
accuracy_measure(table_l2_flat, embedded_df)
# Out:
#   0%|          | 0/6351 [00:00<?, ?it/s]
# 0.7630469392396645

# %%
accuracy_measure(table_ip_flat, embedded_df)
# Out:
#   0%|          | 0/6351 [00:00<?, ?it/s]
# 0.8039984954250424

# %%
accuracy_measure(table_cs_flat, embedded_df)
# Out:
#   0%|          | 0/6351 [00:00<?, ?it/s]
# 0.7634449518011144

# %%
accuracy_measure_ivf(table_l2_ivfpq, nontraindata)
# Out:
#   0%|          | 0/5351 [00:00<?, ?it/s]
# 0.0

# %%
accuracy_measure_ivf(table_ip_ivfpq, nontraindata)
# Out:
#   0%|          | 0/5351 [00:00<?, ?it/s]
# 0.0

# %%
#nontraindata.iloc[1]["embedding"]
table
# Out:
# [0.6492176651954651,
#  0.07765069603919983,
#  0.27312326431274414,
#  8.272551895061042e-06,
#  8.305628862621817e-13,
#  1.8024276732600542e-12,
#  7.084186535999404e-12,
#  3.634183882647579e-12,
#  9.531141501040175e-12,
#  5.258036627625584e-12,
#  3.578987583727211e-12,
#  5.586827007963979e-12,
#  1.1177772249459927e-11,
#  2.2496100034880007e-12,
#  1.0757311708076145e-11,
#  4.086809449882489e-12,
#  2.4562600217659103e-12,
#  1.1839793902235218e-11,
#  1.6976810582325363e-11,
#  6.366511050986956e-12,
#  6.587953273184954e-12,
#  6.23126073309721e-12,
#  5.1799259326301694e-12,
#  5.71759089726398e-12,
#  3.7300735417078457e-11,
#  4.516693876549516e-12,
#  4.104824119499639e-12,
#  2.5216695051510918e-12,
#  1.872785433676416e-11,
#  1.4565438698904698e-12,
#  9.961419709936248e-12,
#  8.055486833136172e-12,
#  3.1067279825103267e-12,
#  1.7503983288855163e-12,
#  5.152002088837371e-12,
#  2.5159141263386697e-12,
#  3.4134463918616964e-12,
#  3.478031057602138e-11,
#  1.1575832306598421e-11,
#  4.9572602967007384e-12,
#  2.9724660233210187e-12,
#  3.5097638770992257e-12,
#  3.856831520820947e-12,
#  7.992965664338492e-12,
#  1.8012110900023082e-12,
#  4.045310527528434e-12,
#  1.75264733281999e-11,
#  9.758040729612727e-12,
#  3.3169933813526065e-12,
#  1.324832929992803e-12,
#  6.588141057001229e-12,
#  2.253840560365039e-12,
#  2.865088158041096e-12,
#  1.063127537392905e-11,
#  4.818452060961764e-12,
#  3.2248958278108253e-12,
#  4.233800809938515e-12,
#  2.346691851257132e-12,
#  4.539269567865878e-12,
#  4.764387235428602e-12,
#  5.747813249662448e-12,
#  8.579926049148701e-13,
#  5.7437258074721775e-12,
#  3.0363990401877095e-12,
#  6.173518727475846e-12,
#  4.160631908445289e-12,
#  1.2132664664599169e-11,
#  1.999803968255609e-11,
#  6.818333658092923e-12,
#  8.169788630330022e-12,
#  1.2668929273706997e-11,
#  4.172926327400406e-12,
#  5.35713227250989e-12,
#  2.9482260816698913e-12,
#  2.3126550587754258e-12,
#  1.6093746344272852e-12,
#  1.5125777366731263e-11,
#  2.002734349887403e-12,
#  7.336979331376559e-13,
#  2.153022335069088e-12,
#  6.044996100906808e-12,
#  4.734601165984342e-12,
#  4.673527623927365e-12,
#  3.1720535486473578e-12,
#  2.1614448512258244e-12,
#  1.5859024163344948e-11,
#  2.018035218098735e-11,
#  3.4081119003326332e-12,
#  1.5130674491103946e-12,
#  3.3239344436608587e-12,
#  2.0413714121869653e-11,
#  3.4095031485603666e-12,
#  2.8495777786019527e-12,
#  2.9334124105467874e-12,
#  2.5330122114392006e-12,
#  8.98467758525534e-12,
#  3.0948459940616235e-12,
#  5.893824057273678e-12,
#  6.032222898272321e-12,
#  9.193901716331165e-12,
#  9.43971788756881e-13,
#  3.144026705648173e-12,
#  5.8429849500440945e-12,
#  4.144316400472858e-12,
#  9.000848026977093e-13,
#  5.492390396655278e-12,
#  6.247334463985177e-13,
#  1.3952365304770176e-11,
#  1.4357246945137514e-12,
#  4.089062855677783e-12,
#  1.776895991456584e-11,
#  2.271543630277817e-12,
#  2.6937198131793405e-12,
#  2.2208972508264146e-11,
#  9.684849493554748e-13,
#  3.567735083059853e-12,
#  2.3879561522610615e-12,
#  3.444591183468515e-12,
#  5.603891916478032e-12,
#  2.2692052230322e-12,
#  5.922616130166203e-12,
#  1.6169595176696028e-11,
#  4.8673439410895636e-12,
#  2.0874465350706473e-11,
#  2.1017037936388316e-12,
#  6.082897640452556e-12,
#  6.914442976513335e-13,
#  5.925949835006161e-12,
#  8.080369706675583e-12,
#  9.388996524695159e-12,
#  1.7672798988122018e-11,
#  7.473035211480461e-12,
#  1.1377096096817918e-12,
#  7.247325027430473e-13,
#  2.90229082086646e-12,
#  5.592242814655979e-12,
#  1.8417331895670408e-11,
#  9.165069397853998e-11,
#  1.4582506209503965e-12,
#  2.42599126551446e-12,
#  4.228549108087343e-11,
#  4.9253101597201976e-12,
#  3.811876595621877e-12,
#  ...]

# %%
#print(nontraindata.iloc[1]["embedding"])
table_l2_ivfpq.search([nontraindata.iloc[1]["embedding"]],n=9)
# Out:
# [  source class embedding  __nn_distance
#  0                     []       0.003918
#  1                     []       0.003918
#  2                     []       0.003918
#  3                     []       0.003918
#  4                     []       0.003918
#  5                     []       0.003918
#  6                     []       0.003918
#  7                     []       0.003918
#  8                     []       0.003918]

# %% [markdown]
# ## 6. Delete the KDB.AI Table
#
# Once finished with the table, it is best practice to drop it.

# %%
table.drop()
# Out:
# True

# %% [markdown]
# ## Take Our Survey
#
# We hope you found this sample helpful! Your feedback is important to us, and we would appreciate it if you could take a moment to fill out our brief survey. Your input helps us improve our content.
#
# [**Take the Survey**](https://delighted.com/t/pmv533GL)
